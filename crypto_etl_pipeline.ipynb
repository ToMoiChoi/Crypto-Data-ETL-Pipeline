# %%
import requests
import pandas as pd
from sqlalchemy import create_engine
from datetime import datetime
import psycopg2
import time

# %%
BINANCE_API_URL = "https://api.binance.com/api/v3/klines"
SYMBOLS = ["BTCUSDT"]  # You can add more pairs
limit=30
interval="1d"
# PostgreSQL connection string
DB_USER = "postgres"
DB_PASSWORD = "200903"
DB_HOST = "localhost"
DB_PORT = "5432"
DB_NAME = "crypto_data"

log_file = "./code_log.txt"
output_path="./crbtc_usdt_30days.csv"
table_name='crypto_prices'

# %%
# Create SQLAlchemy engine
engine = create_engine(f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}")

# %%
def log_progress(message):
    ''' This function logs the mentioned message of a given stage of the
    code execution to a log file. Function returns nothing'''

    timestamp_format = "%Y-%h-%d-%H:%M:%S" # Year-Monthname-Day-Hour-Minute-Second
    now = datetime.now() # get current timestamp
    timestamp = now.strftime(timestamp_format)
    with open(log_file,"a") as f:
        f.write(timestamp + " : " + message + "\n")

# %%
def extract_binance_data(url,SYMBOLS,limit,interval):
    try:
        params = {
            "symbol": SYMBOLS,
            "interval": interval,
            "limit": limit
        }

        response = requests.get(url, params=params)
        response.raise_for_status()  # kiểm tra lỗi HTTP

        data = response.json()

        columns = [
            "Open Time", "Open", "High", "Low", "Close", "Volume",
            "Close Time", "Quote Asset Volume", "Number of Trades",
            "Taker Buy Base Asset Volume", "Taker Buy Quote Asset Volume", "Ignore"
        ]
        df = pd.DataFrame(data, columns=columns)

        # Chuyển đổi kiểu dữ liệu
        df["Open Time"] = pd.to_datetime(df["Open Time"], unit='ms')
        df["Close Time"] = pd.to_datetime(df["Close Time"], unit='ms')
        df[["Open", "High", "Low", "Close", "Volume"]] = df[["Open", "High", "Low", "Close", "Volume"]].astype(float)

        return df
    except Exception as e:
        print(f"❌ Error fetching Binance data: {e}")
        return pd.DataFrame()

# %%
def transform(df):
    df["Daily Change (%)"] = ((df["Close"] - df["Open"]) / df["Open"]) * 100
    df["Date"] = df["Close Time"].dt.date
    df = df[["Date", "Open", "High", "Low", "Close", "Volume", "Daily Change (%)"]]
    return df

# %%
def load_to_csv(df, output_path):
    df.to_csv(output_path)

# %%
def load_to_postgres(df,engine, table_name):
    """Load data into PostgreSQL database."""
    if df.empty:
        log_progress("No data to load.")
        return
    
    df.to_sql(table_name, engine, if_exists="replace", index=False)
    log_progress(f"Loaded {len(df)} rows into '{table_name}' table at")

# %%
def run_query(query_statement, sql_connection):
    ''' This function runs the query on the database table and
    prints the output on the terminal. Function returns nothing. '''

    print(query_statement)
    query_output = pd.read_sql(query_statement, sql_connection)
    print(query_output)

# %%
sql_connection = psycopg2.connect(database=DB_NAME, user=DB_USER, password=DB_PASSWORD, host=DB_HOST, port=DB_PORT)

# %%
log_progress("Preliminaries complete. Initiating ETL process")

    # 1. Extract
df = extract_binance_data(BINANCE_API_URL,SYMBOLS,limit,interval)
print("Extracted data:")
print(df)
log_progress("Data extraction complete. Initiating Transformation process")

# 2. Transform
print("Transformed data:")

print(df)

log_progress("Data transformation complete. Initiating Loading process")

load_to_csv(df, output_path)

log_progress("Data saved to CSV file")
    # 3. Load
load_to_postgres(df,engine,table_name)

log_progress("ETL pipeline completed at")
# Out:
# Extracted data:
#     Open Time       Open       High        Low      Close       Volume  \
# 0  2025-10-18  106431.68  107499.00  106322.20  107185.01  11123.18766
# 10               7765.31574000           887031686.01637250      0
# 11              10407.07233000          1163985607.35690850      0
# 12              12551.13144000          1365671836.74559240      0
# 13              10798.53938000          1185034290.92377970      0
# 14               3406.68401000           375126956.08097220      0
# 15               5921.86453000           654016950.25497770      0
# 16              12847.08574000          1377869106.66817760      0
# 17              23388.99033000          2406186713.17052980      0
# 18              18126.84828000          1854232277.03301110      0
# 19              11972.54796000          1225474173.02042840      0
# 20              16056.80582000          1629564159.11657990      0
# 21               5862.65977000           599611355.36714670      0
# 22               8224.94939000           849620657.08690970      0
# 23              11595.81944000          1226965888.74676980      0
# 24              10717.03395000          1121890584.19977650      0
# 25              10155.72095000          1047214063.13828700      0
# 26              17250.22426000          1742449117.57636070      0
# 27              21184.91518000          2045542286.86348350      0
# 28               7115.78198000           682358960.75404210      0
# 29               4078.57822000           390093627.99633480      0
# C:\Users\viett\AppData\Local\Temp\ipykernel_596\222506705.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   query_output = pd.read_sql(query_statement, sql_connection)

# %%
# !pip install google-cloud-bigquery db_dtypes
# Out:
# Requirement already satisfied: google-cloud-bigquery in d:\user\lib\site-packages (3.38.0)
# Requirement already satisfied: db_dtypes in d:\user\lib\site-packages (1.4.4)
# Requirement already satisfied: google-api-core<3.0.0,>=2.11.1 in d:\user\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (2.28.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in d:\user\lib\site-packages (from google-cloud-bigquery) (2.43.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in d:\user\lib\site-packages (from google-cloud-bigquery) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in d:\user\lib\site-packages (from google-cloud-bigquery) (2.7.2)
# Requirement already satisfied: packaging>=24.2.0 in d:\user\lib\site-packages (from google-cloud-bigquery) (25.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in d:\user\lib\site-packages (from google-cloud-bigquery) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in d:\user\lib\site-packages (from google-cloud-bigquery) (2.32.2)
# Requirement already satisfied: numpy>=1.24.0 in d:\user\lib\site-packages (from db_dtypes) (1.26.4)
# Requirement already satisfied: pandas>=1.5.3 in d:\user\lib\site-packages (from db_dtypes) (2.2.2)
# Requirement already satisfied: pyarrow>=13.0.0 in d:\user\lib\site-packages (from db_dtypes) (21.0.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in d:\user\lib\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in d:\user\lib\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (6.33.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in d:\user\lib\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.26.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in d:\user\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in d:\user\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.76.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in d:\user\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\user\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\user\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (4.9.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in d:\user\lib\site-packages (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery) (1.7.1)
# Requirement already satisfied: pytz>=2020.1 in d:\user\lib\site-packages (from pandas>=1.5.3->db_dtypes) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\user\lib\site-packages (from pandas>=1.5.3->db_dtypes) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\user\lib\site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\user\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\user\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\user\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\user\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2025.11.12)
# Requirement already satisfied: typing-extensions~=4.12 in d:\user\lib\site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (4.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\user\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (0.4.8)

# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import db_dtypes


# Đường dẫn đến file JSON key
key_path = "./airflow/keys/gcp_key.json"

# Tạo credentials
credentials = service_account.Credentials.from_service_account_file(key_path)

# Tạo BigQuery client
client = bigquery.Client(credentials=credentials, project="japanese-food-shop-analysis")

print("✅ Đã kết nối BigQuery thành công!")
# Out:
# ✅ Đã kết nối BigQuery thành công!

# %%
query = "SELECT COUNT(*) AS total_rows, MIN(Open) AS start, MAX(Open) AS `end` FROM `japanese-food-shop-analysis.crypto_dataset.btcusdt_daily`;"
df = client.query(query).to_dataframe()

print(df)
# Out:
# d:\User\Lib\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#    total_rows      start        end
# 0          30  101346.04  114559.41
